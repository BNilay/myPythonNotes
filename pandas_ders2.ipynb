# %%
import pandas as pd
import numpy as np

# %%
my_data = np.array([[10,20,30],[20,30,40],[20,50,10],[10,15,20]])
my_data
# Out:
# array([[10, 20, 30],
#        [20, 30, 40],
#        [20, 50, 10],
#        [10, 15, 20]])

# %%
my_names = ["James","Lars","Kirk","Rob"]

# %%
my_columns = ["Jan","Feb","Mar"]

# %%
my_data_frame = pd.DataFrame(my_data)
my_data_frame
# Out:
#     0   1   2
# 0  10  20  30
# 1  20  30  40
# 2  20  50  10
# 3  10  15  20

# %%
my_data_frame[0]
# Out:
# 0    10
# 1    20
# 2    20
# 3    10
# Name: 0, dtype: int32

# %%
new_data_frame = pd.DataFrame(my_data,index=my_names,columns=my_columns)

# %%
new_data_frame
# Out:
#        Jan  Feb  Mar
# James   10   20   30
# Lars    20   30   40
# Kirk    20   50   10
# Rob     10   15   20

# %%
new_data_frame["Feb"]
# Out:
# James    20
# Lars     30
# Kirk     50
# Rob      15
# Name: Feb, dtype: int32

# %%
feb_series = new_data_frame["Feb"]

# %%
feb_series.mean()
# Out:
# 28.75

# %%
feb_series.Lars
# Out:
# 30

# %%
new_data_frame["Jan"].mean
# Out:
# <bound method Series.mean of James    10
# Lars     20
# Kirk     20
# Rob      10
# Name: Jan, dtype: int32>

# %%
new_data_frame.loc["Lars"]
# Out:
# Jan    20
# Feb    30
# Mar    40
# Name: Lars, dtype: int32

# %%
new_data_frame.iloc[3]
# Out:
# Jan    10
# Feb    15
# Mar    20
# Name: Rob, dtype: int32

# %% [markdown]
# loc → etiket (isim) kullanıyor, bitiş dahil.
#
# iloc → indeks (pozisyon) kullanıyor, bitiş hariç.

# %%
new_data_frame["Apr"]=new_data_frame["Mar"]*2
new_data_frame
# Out:
#        Jan  Feb  Mar  Apr
# James   10   20   30   60
# Lars    20   30   40   80
# Kirk    20   50   10   20
# Rob     10   15   20   40

# %%
new_data_frame.drop("Rob",axis=0)
# Out:
#        Jan  Feb  Mar  Apr
# James   10   20   30   60
# Lars    20   30   40   80
# Kirk    20   50   10   20

# %%
new_data_frame
# Out:
#        Jan  Feb  Mar  Apr
# James   10   20   30   60
# Lars    20   30   40   80
# Kirk    20   50   10   20
# Rob     10   15   20   40

# %%
new_data_frame.drop("Apr",axis=1)
# Out:
#        Jan  Feb  Mar
# James   10   20   30
# Lars    20   30   40
# Kirk    20   50   10
# Rob     10   15   20

# %%
new_data_frame.drop("Apr",axis=1 , inplace=True) #inplace kalıcı olmasını sağlar

# %%
new_data_frame
# Out:
#        Jan  Feb  Mar
# James   10   20   30
# Lars    20   30   40
# Kirk    20   50   10
# Rob     10   15   20

# %%
new_data_frame
# Out:
#        Jan  Feb  Mar
# James   10   20   30
# Lars    20   30   40
# Kirk    20   50   10
# Rob     10   15   20

# %%
new_data_frame["Jan"]["Lars"]
# Out:
# 20

# %%
boolean_frame = new_data_frame>25
boolean_frame
# Out:
#          Jan    Feb    Mar
# James  False  False   True
# Lars   False   True   True
# Kirk   False   True  False
# Rob    False  False  False

# %%
new_data_frame[boolean_frame]
# Out:
#        Jan   Feb   Mar
# James  NaN   NaN  30.0
# Lars   NaN  30.0  40.0
# Kirk   NaN  50.0   NaN
# Rob    NaN   NaN   NaN

# %%
new_data_frame[new_data_frame>30]
# Out:
#        Jan   Feb   Mar
# James  NaN   NaN   NaN
# Lars   NaN   NaN  40.0
# Kirk   NaN  50.0   NaN
# Rob    NaN   NaN   NaN

# %%
new_data_frame[new_data_frame["Mar"]>25]
# Out:
#        Jan  Feb  Mar
# James   10   20   30
# Lars    20   30   40

# %%
new_data_frame.reset_index()
# Out:
#    index  Jan  Feb  Mar
# 0  James   10   20   30
# 1   Lars   20   30   40
# 2   Kirk   20   50   10
# 3    Rob   10   15   20

# %%
new_data_frame["NewIndex"]=["Jam","Lar","Kir","Robert"]

# %%
new_data_frame
# Out:
#        Jan  Feb  Mar NewIndex
# James   10   20   30      Jam
# Lars    20   30   40      Lar
# Kirk    20   50   10      Kir
# Rob     10   15   20   Robert

# %%
new_data_frame.set_index("NewIndex")
# Out:
#           Jan  Feb  Mar
# NewIndex
# Jam        10   20   30
# Lar        20   30   40
# Kir        20   50   10
# Robert     10   15   20

# %%
new_data_frame.drop("NewIndex",axis=1,inplace=True)

# %%
new_data_frame
# Out:
#        Jan  Feb  Mar
# James   10   20   30
# Lars    20   30   40
# Kirk    20   50   10
# Rob     10   15   20
